# %%
# !pip install requests
from requests import Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.6.15)

# %%
from requests import Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

url = 'url of the website api' # Replace with your actual API endpoint
parameters = {
    'start' : '1',
    'limit' : '5000',
    'convert' : 'USD'
}

headers = {
    'Accepts' : 'application/json',
    'X-CMC_PRO_API_KEY' : 'api key from the website' # Replace with your actual API key
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# /tmp/ipython-input-7-3781293470.py in <cell line: 0>()
#      20
#      21 try:
# ---> 22     response = session.get(url, params=parameters)
#      23     data = json.loads(response.text)
#      24     #print(data)
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     600
#     601         kwargs.setdefault("allow_redirects", True)
# --> 602         return self.request("GET", url, **kwargs)
#     603
#     604     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     573             hooks=hooks,
#     574         )
# --> 575         prep = self.prepare_request(req)
#     576
#     577         proxies = proxies or {}
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in prepare_request(self, request)
#     482
#     483         p = PreparedRequest()
# --> 484         p.prepare(
#     485             method=request.method.upper(),
#     486             url=request.url,
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     365
#     366         self.prepare_method(method)
# --> 367         self.prepare_url(url, params)
#     368         self.prepare_headers(headers)
#     369         self.prepare_cookies(cookies)
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in prepare_url(self, url, params)
#     436
#     437         if not scheme:
# --> 438             raise MissingSchema(
#     439                 f"Invalid URL {url!r}: No scheme supplied. "
#     440                 f"Perhaps you meant https://{url}?"
#
# MissingSchema: Invalid URL 'url of the website api': No scheme supplied. Perhaps you meant https://url of the website api?

# %%
# type(data)

import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pd.json_normalize(data['data'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3-1414037439.py in <cell line: 0>()
# ----> 1 pd.json_normalize(data['data'])
#       2
#
# NameError: name 'data' is not defined

# %%
#poke api

# %%
import requests

# %%
base_url = "https://pokeapi.co/api/v2/"

def get_pokemon_info(name):
    url = base_url + "pokemon/" + name #url = f"{base_url}/pokemon/{name}"
    response = requests.get(url)

    if response.status_code == 200:
        pokemon_data = response.json()
        return pokemon_data
    else:
        print(f"Error: {response.status_code}")
        return None


pokemon_name = "ditto"
pokemon_info = get_pokemon_info(pokemon_name)

if pokemon_info:
    print(f"name: {pokemon_info["name"]}")
else:
    print("Pokemon not found.")
